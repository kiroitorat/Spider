# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 属性有:
# ## ndim:维度
# ## shape:形状(各维度的长度)
# ## size:总长度
# ## dtype

# %%
cat = np.random.randint(0, 255, (3,3,3), np.int16)
cat
# Out:
# array([[[ 85, 217, 222],
#         [249, 137,  97],
#         [121, 191, 132]],
#
#        [[ 75,  59, 195],
#         [ 89,  20, 171],
#         [117,   0, 113]],
#
#        [[117,  99,  91],
#         [ 98,  25, 222],
#         [102, 127, 215]]], dtype=int16)

# %%
cat.shape
# Out:
# (3, 3, 3)

# %%
cat.size
# Out:
# 27

# %%
cat.ndim
# Out:
# 3

# %%
cat.dtype
# Out:
# dtype('int16')

# %% [markdown]
# # 操作:
# ## 1.索引
# ## 2.切片

# %%
cat_part = cat[2][2][2]
cat_part
# Out:
# 215

# %% [markdown]
# 或者可以简写为[2,2,2]

# %% [markdown]
# ## 切片跟python一致

# %%
cat_slide = cat[:3]
cat_slide
# Out:
# array([[[ 85, 217, 222],
#         [249, 137,  97],
#         [121, 191, 132]],
#
#        [[ 75,  59, 195],
#         [ 89,  20, 171],
#         [117,   0, 113]],
#
#        [[117,  99,  91],
#         [ 98,  25, 222],
#         [102, 127, 215]]], dtype=int16)

# %% [markdown]
# ## 切片二维及以上的需要用到以下方式

# %%
ex_a_2 = np.random.randint(1, 20, (3,3,2))
ex_a_3 = np.random.randint(1, 20, (3,3,3))

# %%
print(ex_a_2)
# Out:
# [[[15  1]
#   [ 1  5]
#   [ 7  1]]
#
#  [[14 15]
#   [13 17]
#   [13  2]]
#
#  [[ 8  1]
#   [ 9 16]
#   [ 7  6]]]

# %%
ex_a_3
# Out:
# array([[[15, 16, 16],
#         [ 1,  5, 19],
#         [14, 14,  8]],
#
#        [[ 5, 19,  9],
#         [ 3, 11,  6],
#         [15, 12,  5]],
#
#        [[15, 11,  5],
#         [ 9,  9, 10],
#         [19, 17,  7]]])

# %% [markdown]
# ### 取二维数组的某不连续的行
# #### 例:取1,3行

# %%
ex_a_2_slide = ex_a_2[[0,2]]
ex_a_2_slide
# Out:
# array([[[15,  1],
#         [ 1,  5],
#         [ 7,  1]],
#
#        [[ 8,  1],
#         [ 9, 16],
#         [ 7,  6]]])

# %% [markdown]
# ###  取行使用切片+索引  [切片, 索引]
# #### 例:取第二列

# %%
ex_a_2[0:3,1]
# Out:
# array([[ 1,  5],
#        [13, 17],
#        [ 9, 16]])

# %% [markdown]
# #### 例:取1,3列

# %%
ex_a_2[:, [0,2]]
# Out:
# array([[[15,  1],
#         [ 7,  1]],
#
#        [[14, 15],
#         [13,  2]],
#
#        [[ 8,  1],
#         [ 7,  6]]])

# %%
cat_array = plt.imread('猫猫啃苹果.jpg')
cat_array
# Out:
# array([[[255, 254, 253],
#         [255, 254, 253],
#         [255, 254, 255],
#         ...,
#         [255, 255, 253],
#         [255, 255, 253],
#         [255, 255, 251]],
#
#        [[255, 254, 253],
#         [255, 254, 253],
#         [255, 254, 255],
#         ...,
#         [255, 255, 253],
#         [255, 255, 253],
#         [255, 255, 251]],
#
#        [[255, 254, 253],
#         [255, 254, 253],
#         [255, 254, 255],
#         ...,
#         [255, 255, 253],
#         [255, 255, 253],
#         [255, 255, 251]],
#
#        ...,
#
#        [[ 80,  58,  61],
#         [ 80,  58,  61],
#         [ 80,  58,  61],
#         ...,
#         [ 88,  67,  72],
#         [ 97,  74,  80],
#         [ 97,  74,  80]],
#
#        [[ 80,  58,  61],
#         [ 80,  58,  61],
#         [ 80,  58,  61],
#         ...,
#         [ 86,  65,  70],
#         [ 94,  71,  77],
#         [ 95,  72,  78]],
#
#        [[ 80,  58,  61],
#         [ 80,  58,  61],
#         [ 80,  58,  61],
# ...

# %%
plt.imshow(cat_array)

# %%
plt.imshow(cat_array[ ::-1,::-1])

# %% [markdown]
# #### 第三个元素是rgb

# %%
plt.imshow(cat_array[:,:,::-1])
