# %% [markdown]
# 数据分析三剑客

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
np.__version__
# Out:
# '1.25.2'

# %%
cat_array = plt.imread('猫猫啃苹果.jpg')
cat_array
##使用plt.imread读取图片,类型就是n维数组
# Out:
# array([[[255, 254, 253],
#         [255, 254, 253],
#         [255, 254, 255],
#         ...,
#         [255, 255, 253],
#         [255, 255, 253],
#         [255, 255, 251]],
#
#        [[255, 254, 253],
#         [255, 254, 253],
#         [255, 254, 255],
#         ...,
#         [255, 255, 253],
#         [255, 255, 253],
#         [255, 255, 251]],
#
#        [[255, 254, 253],
#         [255, 254, 253],
#         [255, 254, 255],
#         ...,
#         [255, 255, 253],
#         [255, 255, 253],
#         [255, 255, 251]],
#
#        ...,
#
#        [[ 80,  58,  61],
#         [ 80,  58,  61],
#         [ 80,  58,  61],
#         ...,
#         [ 88,  67,  72],
#         [ 97,  74,  80],
#         [ 97,  74,  80]],
#
#        [[ 80,  58,  61],
#         [ 80,  58,  61],
#         [ 80,  58,  61],
#         ...,
#         [ 86,  65,  70],
#         [ 94,  71,  77],
#         [ 95,  72,  78]],
#
#        [[ 80,  58,  61],
#         [ 80,  58,  61],
#         [ 80,  58,  61],
# ...

# %%
##图片的类型就是n元矩阵
type(cat_array)
# Out:
# numpy.ndarray

# %%
#前面两个参数就是分辨率，最后一个参数是维度
cat_array.shape
# Out:
# (2048, 1450, 3)

# %% [markdown]
# #显示图片

# %%
plt.imshow(cat_array)
